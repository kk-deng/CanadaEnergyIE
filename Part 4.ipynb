# %% [markdown]
# # Data Extraction

# %%
# Dependencies and Setup
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st

# File to Load 
energy_data_filepath = "Resources/Raw Data/Table 5 - Canadian Electricity by source.csv"

# Read Data File and store into Pandas DataFrames
raw_energy_data = pd.read_csv(energy_data_filepath)
raw_energy_data.head()
# Out:
#    REF_DATE     GEO           DGUID  \
# 0      2005  Canada  2016A000011124
# 1      2005  Canada  2016A000011124
# 2      2005  Canada  2016A000011124
# 3      2005  Canada  2016A000011124
# 4      2005  Canada  2016A000011124
#
#                Class of electricity producer  \
# 0  Total all classes of electricity producer
# 1  Total all classes of electricity producer
# 2  Total all classes of electricity producer
# 3  Total all classes of electricity producer
# 4  Total all classes of electricity producer
#
#                       Type of electricity generation             UOM  UOM_ID  \
# 0          Total all types of electricity generation  Megawatt hours     210
# 1  Total hydro, tidal, wind, solar and other gene...  Megawatt hours     210
# 2                                  Hydraulic turbine  Megawatt hours     210
# 3                                Tidal power turbine  Megawatt hours     210
# 4                                 Wind power turbine  Megawatt hours     210
#
#   SCALAR_FACTOR  SCALAR_ID     VECTOR COORDINATE        VALUE STATUS SYMBOL  \
# 0        units           0  v52300346      1.1.1  604369965.0    NaN    NaN
# 1        units           0  v52300348      1.1.2  360025505.0    NaN    NaN
# 2        units           0  v52300349      1.1.3  358446082.0    NaN    NaN
# 3        units           0  v52300350      1.1.4      27643.0    NaN    NaN
# 4        units           0  v52300351      1.1.5    1551780.0    NaN    NaN
#
#    TERMINATED  DECIMALS
# 0         NaN         0
# 1         NaN         0
# 2         NaN         0
# 3         NaN         0
# 4         NaN         0

# %% [markdown]
# ## Extract and Clean Raw Energy Data

# %%
# Select the columns of concerns
clean_energy_data1 = raw_energy_data[["REF_DATE","GEO","Class of electricity producer","Type of electricity generation","VALUE"]]
clean_energy_data1
# Out:
#       REF_DATE      GEO              Class of electricity producer  \
# 0         2005   Canada  Total all classes of electricity producer
# 1         2005   Canada  Total all classes of electricity producer
# 2         2005   Canada  Total all classes of electricity producer
# 3         2005   Canada  Total all classes of electricity producer
# 4         2005   Canada  Total all classes of electricity producer
# ...        ...      ...                                        ...
# 4828      2019  Nunavut  Total all classes of electricity producer
# 4829      2019  Nunavut   Electricity producer, electric utilities
# 4830      2019  Nunavut   Electricity producer, electric utilities
# 4831      2019  Nunavut   Electricity producer, electric utilities
# 4832      2019  Nunavut   Electricity producer, electric utilities
#
#                          Type of electricity generation        VALUE
# 0             Total all types of electricity generation  604369965.0
# 1     Total hydro, tidal, wind, solar and other gene...  360025505.0
# 2                                     Hydraulic turbine  358446082.0
# 3                                   Tidal power turbine      27643.0
# 4                                    Wind power turbine    1551780.0
# ...                                                 ...          ...
# 4828  Total electricity production from combustible ...     192222.0
# 4829          Total all types of electricity generation     192222.0
# 4830                           Total thermal generation     192222.0
# 4831                        Internal combustion turbine          NaN
# 4832  Total electricity production from combustible ...     192222.0
#
# [4833 rows x 5 columns]

# %%
# Select data for the entire Canada and total class of electricity producer
clean_energy_data2 =clean_energy_data1[(clean_energy_data1["GEO"] == "Canada") & 
                                       (clean_energy_data1["Class of electricity producer"] 
                                       == "Total all classes of electricity producer")]
clean_energy_data2
# Out:
#       REF_DATE     GEO              Class of electricity producer  \
# 0         2005  Canada  Total all classes of electricity producer
# 1         2005  Canada  Total all classes of electricity producer
# 2         2005  Canada  Total all classes of electricity producer
# 3         2005  Canada  Total all classes of electricity producer
# 4         2005  Canada  Total all classes of electricity producer
# ...        ...     ...                                        ...
# 4470      2019  Canada  Total all classes of electricity producer
# 4471      2019  Canada  Total all classes of electricity producer
# 4472      2019  Canada  Total all classes of electricity producer
# 4473      2019  Canada  Total all classes of electricity producer
# 4474      2019  Canada  Total all classes of electricity producer
#
#                          Type of electricity generation        VALUE
# 0             Total all types of electricity generation  604369965.0
# 1     Total hydro, tidal, wind, solar and other gene...  360025505.0
# 2                                     Hydraulic turbine  358446082.0
# 3                                   Tidal power turbine      27643.0
# 4                                    Wind power turbine    1551780.0
# ...                                                 ...          ...
# 4470                         Conventional steam turbine          NaN
# 4471                              Nuclear steam turbine   95469256.0
# 4472                        Internal combustion turbine          NaN
# 4473                                 Combustion turbine          NaN
# 4474  Total electricity production from combustible ...  127263359.0
#
# [182 rows x 5 columns]

# %%
# Change column name
clean_energy_data3 = clean_energy_data2.rename(columns = {"REF_DATE" : "Year"})
clean_energy_data3
# Out:
#       Year     GEO              Class of electricity producer  \
# 0     2005  Canada  Total all classes of electricity producer
# 1     2005  Canada  Total all classes of electricity producer
# 2     2005  Canada  Total all classes of electricity producer
# 3     2005  Canada  Total all classes of electricity producer
# 4     2005  Canada  Total all classes of electricity producer
# ...    ...     ...                                        ...
# 4470  2019  Canada  Total all classes of electricity producer
# 4471  2019  Canada  Total all classes of electricity producer
# 4472  2019  Canada  Total all classes of electricity producer
# 4473  2019  Canada  Total all classes of electricity producer
# 4474  2019  Canada  Total all classes of electricity producer
#
#                          Type of electricity generation        VALUE
# 0             Total all types of electricity generation  604369965.0
# 1     Total hydro, tidal, wind, solar and other gene...  360025505.0
# 2                                     Hydraulic turbine  358446082.0
# 3                                   Tidal power turbine      27643.0
# 4                                    Wind power turbine    1551780.0
# ...                                                 ...          ...
# 4470                         Conventional steam turbine          NaN
# 4471                              Nuclear steam turbine   95469256.0
# 4472                        Internal combustion turbine          NaN
# 4473                                 Combustion turbine          NaN
# 4474  Total electricity production from combustible ...  127263359.0
#
# [182 rows x 5 columns]

# %%
# Genearate a pivot table for the electricity production of each energy type by year
final_energy_data = pd.pivot_table(clean_energy_data3, index="Year", columns="Type of electricity generation", 
                                      values="VALUE", aggfunc=sum, fill_value = 0).rename_axis(None, axis=1)
final_energy_data
# Out:
#       Combustion turbine  Conventional steam turbine  Hydraulic turbine  \
# Year
# 2005            25892974                   130320252          358446082
# 2006            25811955                   118877657          349468303
# 2007            32237570                   127778534          364055135
# 2008            30782510                   117666179          373822743
# 2009            32728246                   102607748          365110421
# 2010            38019362                   103118558          347980845
# 2011            44283027                    99411207          372076377
# 2012            45330296                    89871261          376574355
# 2013            43756123                    90388012          387980873
# 2014                   0                           0          378786255
# 2015                   0                           0          378481214
# 2016                   0                           0          381687991
# 2017                   0                           0          390751401
# 2018                   0                           0          382144912
# 2019                   0                           0          375982127
#
#       Internal combustion turbine  Nuclear steam turbine  \
# Year
# 2005                      1301338               86829896
# 2006                      3591329               92418514
# 2007                      1498789               88190431
# 2008                      1425052               90585015
# 2009                      1570922               84991779
# 2010                      1615274               85526588
# 2011                      1609096               88291216
# 2012                      1555195               89492389
# 2013                      1645827               97584431
# 2014                            0              101207807
# 2015                            0               96045793
# 2016                            0               95687312
# 2017                            0               95565022
# 2018                            0               95029596
# 2019                            0               95469256
#
#       Other types of electricity generation    Solar  Tidal power turbine  \
# Year
# 2005                                      0        0                27643
# 2006                                      0        0                19144
# 2007                                      0        0                22524
# 2008                                      0        0                15018
# 2009                                1918497     4502                29954
# 2010                                2975953   115745                27680
# 2011                                2509521   256935                26095
# 2012                                2723937   315843                27128
# 2013                                2441392   360478                14830
# 2014                                2238903   325184                15483
# 2015                                 139421  1426619                12820
# 2016                                 177803  1779083                18547
# 2017                                 202863  2001842                 5957
# 2018                                 210747  2192046                19525
# 2019                                 168289  2195412                  920
#
#       Total all types of electricity generation  \
# Year
# 2005                                  604369965
# 2006                                  592635237
# 2007                                  616760189
# 2008                                  618047146
# 2009                                  595537304
# 2010                                  588016955
# 2011                                  618550162
# 2012                                  617088777
# 2013                                  635205955
# 2014                                  629581402
# 2015                                  640327058
# 2016                                  646331002
# 2017                                  648919804
# 2018                                  640326756
# 2019                                  633412436
#
#       Total electricity production from combustible fuels  \
# Year
# 2005                                                  0
# 2006                                                  0
# 2007                                                  0
# 2008                                                  0
# 2009                                                  0
# 2010                                                  0
# 2011                                                  0
# 2012                                                  0
# 2013                                                  0
# 2014                                          134318871
# 2015                                          137524464
# 2016                                          136356480
# 2017                                          129194240
# 2018                                          127916909
# 2019                                          127263359
#
#       Total hydro, tidal, wind, solar and other generation  \
# Year
# 2005                                          360025505
# 2006                                          351935782
# 2007                                          367054865
# 2008                                          377588390
# 2009                                          373638609
# 2010                                          359737173
# 2011                                          384955616
# 2012                                          390839636
# 2013                                          401831562
# 2014                                          394054724
# 2015                                          406756801
# 2016                                          414287210
# 2017                                          424160542
# 2018                                          417380251
# 2019                                          410679821
#
#       Total thermal generation  Wind power turbine
# Year
# 2005                 244344460             1551780
# 2006                 240699455             2448335
# 2007                 249705324             2977206
# 2008                 240458756             3750629
# 2009                 221898695             6575235
# 2010                 228279782             8636950
# 2011                 233594546            10086688
# 2012                 226249141            11198373
# 2013                 233374393            11033989
# 2014                 235526678            12688899
# 2015                 233570257            26696727
# 2016                 232043792            30623786
# 2017                 224759262            31198479
# 2018                 222946505            32813021
# 2019                 222732615            32333073

# %% [markdown]
# ## Use Raw Data to Generate Renewable Energy Data

# %%
# Select renewable energy columns
renewable_energy_data = final_energy_data[["Hydraulic turbine", "Solar", "Tidal power turbine", "Wind power turbine",
                                             "Other types of electricity generation",
                                             "Total hydro, tidal, wind, solar and other generation"]]
renewable_energy_data
# Out:
#       Hydraulic turbine    Solar  Tidal power turbine  Wind power turbine  \
# Year
# 2005          358446082        0                27643             1551780
# 2006          349468303        0                19144             2448335
# 2007          364055135        0                22524             2977206
# 2008          373822743        0                15018             3750629
# 2009          365110421     4502                29954             6575235
# 2010          347980845   115745                27680             8636950
# 2011          372076377   256935                26095            10086688
# 2012          376574355   315843                27128            11198373
# 2013          387980873   360478                14830            11033989
# 2014          378786255   325184                15483            12688899
# 2015          378481214  1426619                12820            26696727
# 2016          381687991  1779083                18547            30623786
# 2017          390751401  2001842                 5957            31198479
# 2018          382144912  2192046                19525            32813021
# 2019          375982127  2195412                  920            32333073
#
#       Other types of electricity generation  \
# Year
# 2005                                      0
# 2006                                      0
# 2007                                      0
# 2008                                      0
# 2009                                1918497
# 2010                                2975953
# 2011                                2509521
# 2012                                2723937
# 2013                                2441392
# 2014                                2238903
# 2015                                 139421
# 2016                                 177803
# 2017                                 202863
# 2018                                 210747
# 2019                                 168289
#
#       Total hydro, tidal, wind, solar and other generation
# Year
# 2005                                          360025505
# 2006                                          351935782
# 2007                                          367054865
# 2008                                          377588390
# 2009                                          373638609
# 2010                                          359737173
# 2011                                          384955616
# 2012                                          390839636
# 2013                                          401831562
# 2014                                          394054724
# 2015                                          406756801
# 2016                                          414287210
# 2017                                          424160542
# 2018                                          417380251
# 2019                                          410679821

# %%
# Rename the total column
renewable_energy_data = renewable_energy_data.rename(columns = {
    "Total hydro, tidal, wind, solar and other generation" : "Total renewable energy generation"
})
renewable_energy_data
# Out:
#       Hydraulic turbine    Solar  Tidal power turbine  Wind power turbine  \
# Year
# 2005          358446082        0                27643             1551780
# 2006          349468303        0                19144             2448335
# 2007          364055135        0                22524             2977206
# 2008          373822743        0                15018             3750629
# 2009          365110421     4502                29954             6575235
# 2010          347980845   115745                27680             8636950
# 2011          372076377   256935                26095            10086688
# 2012          376574355   315843                27128            11198373
# 2013          387980873   360478                14830            11033989
# 2014          378786255   325184                15483            12688899
# 2015          378481214  1426619                12820            26696727
# 2016          381687991  1779083                18547            30623786
# 2017          390751401  2001842                 5957            31198479
# 2018          382144912  2192046                19525            32813021
# 2019          375982127  2195412                  920            32333073
#
#       Other types of electricity generation  Total renewable energy generation
# Year
# 2005                                      0                          360025505
# 2006                                      0                          351935782
# 2007                                      0                          367054865
# 2008                                      0                          377588390
# 2009                                1918497                          373638609
# 2010                                2975953                          359737173
# 2011                                2509521                          384955616
# 2012                                2723937                          390839636
# 2013                                2441392                          401831562
# 2014                                2238903                          394054724
# 2015                                 139421                          406756801
# 2016                                 177803                          414287210
# 2017                                 202863                          424160542
# 2018                                 210747                          417380251
# 2019                                 168289                          410679821

# %%
# Output this cleaned renewable energy production table
renewable_energy_data.to_csv("Resources/Clean Data/Table 5a.csv")

# %% [markdown]
# ## Use Raw Data to Generate Oil Energy Data

# %%
# Select oil energy columns
oil_energy_data = final_energy_data[["Combustion turbine", "Conventional steam turbine","Internal combustion turbine",
                                     "Nuclear steam turbine","Total electricity production from combustible fuels",
                                     "Total thermal generation"]]
oil_energy_data
# Out:
#       Combustion turbine  Conventional steam turbine  \
# Year
# 2005            25892974                   130320252
# 2006            25811955                   118877657
# 2007            32237570                   127778534
# 2008            30782510                   117666179
# 2009            32728246                   102607748
# 2010            38019362                   103118558
# 2011            44283027                    99411207
# 2012            45330296                    89871261
# 2013            43756123                    90388012
# 2014                   0                           0
# 2015                   0                           0
# 2016                   0                           0
# 2017                   0                           0
# 2018                   0                           0
# 2019                   0                           0
#
#       Internal combustion turbine  Nuclear steam turbine  \
# Year
# 2005                      1301338               86829896
# 2006                      3591329               92418514
# 2007                      1498789               88190431
# 2008                      1425052               90585015
# 2009                      1570922               84991779
# 2010                      1615274               85526588
# 2011                      1609096               88291216
# 2012                      1555195               89492389
# 2013                      1645827               97584431
# 2014                            0              101207807
# 2015                            0               96045793
# 2016                            0               95687312
# 2017                            0               95565022
# 2018                            0               95029596
# 2019                            0               95469256
#
#       Total electricity production from combustible fuels  \
# Year
# 2005                                                  0
# 2006                                                  0
# 2007                                                  0
# 2008                                                  0
# 2009                                                  0
# 2010                                                  0
# 2011                                                  0
# 2012                                                  0
# 2013                                                  0
# 2014                                          134318871
# 2015                                          137524464
# 2016                                          136356480
# 2017                                          129194240
# 2018                                          127916909
# 2019                                          127263359
#
#       Total thermal generation
# Year
# 2005                 244344460
# 2006                 240699455
# 2007                 249705324
# 2008                 240458756
# 2009                 221898695
# 2010                 228279782
# 2011                 233594546
# 2012                 226249141
# 2013                 233374393
# 2014                 235526678
# 2015                 233570257
# 2016                 232043792
# 2017                 224759262
# 2018                 222946505
# 2019                 222732615

# %%
# Combined columns that contain 0 into one complete column
oil_energy_data["Combustion fuels"] = (oil_energy_data["Combustion turbine"] + 
                                        oil_energy_data["Conventional steam turbine"] + 
                                        oil_energy_data["Internal combustion turbine"] + 
                                        oil_energy_data["Total electricity production from combustible fuels"])
oil_energy_data
# Out:
# C:\Users\laich\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#       Combustion turbine  Conventional steam turbine  \
# Year
# 2005            25892974                   130320252
# 2006            25811955                   118877657
# 2007            32237570                   127778534
# 2008            30782510                   117666179
# 2009            32728246                   102607748
# 2010            38019362                   103118558
# 2011            44283027                    99411207
# 2012            45330296                    89871261
# 2013            43756123                    90388012
# 2014                   0                           0
# 2015                   0                           0
# 2016                   0                           0
# 2017                   0                           0
# 2018                   0                           0
# 2019                   0                           0
#
#       Internal combustion turbine  Nuclear steam turbine  \
# Year
# 2005                      1301338               86829896
# 2006                      3591329               92418514
# 2007                      1498789               88190431
# 2008                      1425052               90585015
# 2009                      1570922               84991779
# 2010                      1615274               85526588
# 2011                      1609096               88291216
# 2012                      1555195               89492389
# 2013                      1645827               97584431
# 2014                            0              101207807
# 2015                            0               96045793
# 2016                            0               95687312
# 2017                            0               95565022
# 2018                            0               95029596
# 2019                            0               95469256
#
#       Total electricity production from combustible fuels  \
# Year
# 2005                                                  0
# 2006                                                  0
# 2007                                                  0
# 2008                                                  0
# 2009                                                  0
# 2010                                                  0
# 2011                                                  0
# 2012                                                  0
# 2013                                                  0
# 2014                                          134318871
# 2015                                          137524464
# 2016                                          136356480
# 2017                                          129194240
# 2018                                          127916909
# 2019                                          127263359
#
#       Total thermal generation  Combustion fuels
# Year
# 2005                 244344460         157514564
# 2006                 240699455         148280941
# 2007                 249705324         161514893
# 2008                 240458756         149873741
# 2009                 221898695         136906916
# 2010                 228279782         142753194
# 2011                 233594546         145303330
# 2012                 226249141         136756752
# 2013                 233374393         135789962
# 2014                 235526678         134318871
# 2015                 233570257         137524464
# 2016                 232043792         136356480
# 2017                 224759262         129194240
# 2018                 222946505         127916909
# 2019                 222732615         127263359

# %%
# Use the combined column as new table
oil_energy_data = oil_energy_data[["Combustion fuels", "Nuclear steam turbine", "Total thermal generation"]]
oil_energy_data
# Out:
#       Combustion fuels  Nuclear steam turbine  Total thermal generation
# Year
# 2005         157514564               86829896                 244344460
# 2006         148280941               92418514                 240699455
# 2007         161514893               88190431                 249705324
# 2008         149873741               90585015                 240458756
# 2009         136906916               84991779                 221898695
# 2010         142753194               85526588                 228279782
# 2011         145303330               88291216                 233594546
# 2012         136756752               89492389                 226249141
# 2013         135789962               97584431                 233374393
# 2014         134318871              101207807                 235526678
# 2015         137524464               96045793                 233570257
# 2016         136356480               95687312                 232043792
# 2017         129194240               95565022                 224759262
# 2018         127916909               95029596                 222946505
# 2019         127263359               95469256                 222732615

# %%
# Output this cleaned oil energy production table
oil_energy_data.to_csv("Resources/Clean Data/Table 5b.csv")

# %% [markdown]
# ## Extract and Clean Currency Data

# %%
# File to Load 
currency_data_filepath = "Resources/Clean Data/Monthly_Exchange_Rate.csv"

# Read Data File and store into Pandas DataFrames
raw_currency_data = pd.read_csv(currency_data_filepath)
raw_currency_data.head()
# Out:
#          Date   USD/CAD   CAD/USD
# 0  2005-01-01  1.205198  0.829739
# 1  2005-02-01  1.239963  0.806476
# 2  2005-03-01  1.233808  0.810499
# 3  2005-04-01  1.214291  0.823526
# 4  2005-05-01  1.249595  0.800259

# %%
# Extreact from date column to get year 
raw_currency_data["Year"] = raw_currency_data["Date"].str[0:4] 
raw_currency_data
# Out:
#            Date   USD/CAD   CAD/USD  Year
# 0    2005-01-01  1.205198  0.829739  2005
# 1    2005-02-01  1.239963  0.806476  2005
# 2    2005-03-01  1.233808  0.810499  2005
# 3    2005-04-01  1.214291  0.823526  2005
# 4    2005-05-01  1.249595  0.800259  2005
# ..          ...       ...       ...   ...
# 185  2020-06-01  1.369917  0.729971  2020
# 186  2020-07-01  1.358661  0.736019  2020
# 187  2020-08-01  1.341830  0.745251  2020
# 188  2020-09-01  1.301410  0.768397  2020
# 189  2020-10-01  1.328795  0.752561  2020
#
# [190 rows x 4 columns]

# %%
# Groupby to get yearly currency data
yearly_exchange_rate = pd.DataFrame(raw_currency_data.groupby("Year")["CAD/USD"].mean())
yearly_exchange_rate
# Out:
#        CAD/USD
# Year
# 2005  0.825173
# 2006  0.883881
# 2007  0.930507
# 2008  0.955629
# 2009  0.874752
# 2010  0.963620
# 2011  1.016032
# 2012  0.999054
# 2013  0.971670
# 2014  0.908495
# 2015  0.788476
# 2016  0.755048
# 2017  0.767798
# 2018  0.774668
# 2019  0.751779
# 2020  0.742354

# %%
# Change column name
yearly_exchange_rate = yearly_exchange_rate.rename(columns = {"CAD/USD" : "Candian Dollar Index"})
yearly_exchange_rate
# Out:
#       Candian Dollar Index
# Year
# 2005              0.825173
# 2006              0.883881
# 2007              0.930507
# 2008              0.955629
# 2009              0.874752
# 2010              0.963620
# 2011              1.016032
# 2012              0.999054
# 2013              0.971670
# 2014              0.908495
# 2015              0.788476
# 2016              0.755048
# 2017              0.767798
# 2018              0.774668
# 2019              0.751779
# 2020              0.742354

# %%
# Output this cleaned yearly exchange rate table
yearly_exchange_rate.to_csv("Resources/Clean Data/Table 6.csv")

# %% [markdown]
# # Data Transformation

# %%
# File to Load 
renewable_data_filepath = "Resources/Clean Data/Table 5a.csv"
oil_data_filepath = "Resources/Clean Data/Table 5b.csv"
yearly_currency_filepath = "Resources/Clean Data/Table 6.csv"

# Read Data File and store into Pandas DataFrames
renewable_energy_data = pd.read_csv(renewable_data_filepath)
oil_energy_data = pd.read_csv(oil_data_filepath)
yearly_currency_data = pd.read_csv(yearly_currency_filepath)

# %%
# Combine the three data together
merged_canada_data = pd.merge(yearly_currency_data, renewable_energy_data, on = "Year", how = "inner")
merged_canada_data = pd.merge(merged_canada_data, oil_energy_data, on = "Year", how = "inner")
merged_canada_data
# Out:
#     Year  Candian Dollar Index  Hydraulic turbine    Solar  \
# 0   2005              0.825173          358446082        0
# 1   2006              0.883881          349468303        0
# 2   2007              0.930507          364055135        0
# 3   2008              0.955629          373822743        0
# 4   2009              0.874752          365110421     4502
# 5   2010              0.963620          347980845   115745
# 6   2011              1.016032          372076377   256935
# 7   2012              0.999054          376574355   315843
# 8   2013              0.971670          387980873   360478
# 9   2014              0.908495          378786255   325184
# 10  2015              0.788476          378481214  1426619
# 11  2016              0.755048          381687991  1779083
# 12  2017              0.767798          390751401  2001842
# 13  2018              0.774668          382144912  2192046
# 14  2019              0.751779          375982127  2195412
#
#     Tidal power turbine  Wind power turbine  \
# 0                 27643             1551780
# 1                 19144             2448335
# 2                 22524             2977206
# 3                 15018             3750629
# 4                 29954             6575235
# 5                 27680             8636950
# 6                 26095            10086688
# 7                 27128            11198373
# 8                 14830            11033989
# 9                 15483            12688899
# 10                12820            26696727
# 11                18547            30623786
# 12                 5957            31198479
# 13                19525            32813021
# 14                  920            32333073
#
#     Other types of electricity generation  Total renewable energy generation  \
# 0                                       0                          360025505
# 1                                       0                          351935782
# 2                                       0                          367054865
# 3                                       0                          377588390
# 4                                 1918497                          373638609
# 5                                 2975953                          359737173
# 6                                 2509521                          384955616
# 7                                 2723937                          390839636
# 8                                 2441392                          401831562
# 9                                 2238903                          394054724
# 10                                 139421                          406756801
# 11                                 177803                          414287210
# 12                                 202863                          424160542
# 13                                 210747                          417380251
# 14                                 168289                          410679821
#
#     Combustion fuels  Nuclear steam turbine  Total thermal generation
# 0          157514564               86829896                 244344460
# 1          148280941               92418514                 240699455
# 2          161514893               88190431                 249705324
# 3          149873741               90585015                 240458756
# 4          136906916               84991779                 221898695
# 5          142753194               85526588                 228279782
# 6          145303330               88291216                 233594546
# 7          136756752               89492389                 226249141
# 8          135789962               97584431                 233374393
# 9          134318871              101207807                 235526678
# 10         137524464               96045793                 233570257
# 11         136356480               95687312                 232043792
# 12         129194240               95565022                 224759262
# 13         127916909               95029596                 222946505
# 14         127263359               95469256                 222732615

# %%
merged_canada_data = merged_canada_data.set_index("Year")
merged_canada_data
# Out:
#       Candian Dollar Index  Hydraulic turbine    Solar  Tidal power turbine  \
# Year
# 2005              0.825173          358446082        0                27643
# 2006              0.883881          349468303        0                19144
# 2007              0.930507          364055135        0                22524
# 2008              0.955629          373822743        0                15018
# 2009              0.874752          365110421     4502                29954
# 2010              0.963620          347980845   115745                27680
# 2011              1.016032          372076377   256935                26095
# 2012              0.999054          376574355   315843                27128
# 2013              0.971670          387980873   360478                14830
# 2014              0.908495          378786255   325184                15483
# 2015              0.788476          378481214  1426619                12820
# 2016              0.755048          381687991  1779083                18547
# 2017              0.767798          390751401  2001842                 5957
# 2018              0.774668          382144912  2192046                19525
# 2019              0.751779          375982127  2195412                  920
#
#       Wind power turbine  Other types of electricity generation  \
# Year
# 2005             1551780                                      0
# 2006             2448335                                      0
# 2007             2977206                                      0
# 2008             3750629                                      0
# 2009             6575235                                1918497
# 2010             8636950                                2975953
# 2011            10086688                                2509521
# 2012            11198373                                2723937
# 2013            11033989                                2441392
# 2014            12688899                                2238903
# 2015            26696727                                 139421
# 2016            30623786                                 177803
# 2017            31198479                                 202863
# 2018            32813021                                 210747
# 2019            32333073                                 168289
#
#       Total renewable energy generation  Combustion fuels  \
# Year
# 2005                          360025505         157514564
# 2006                          351935782         148280941
# 2007                          367054865         161514893
# 2008                          377588390         149873741
# 2009                          373638609         136906916
# 2010                          359737173         142753194
# 2011                          384955616         145303330
# 2012                          390839636         136756752
# 2013                          401831562         135789962
# 2014                          394054724         134318871
# 2015                          406756801         137524464
# 2016                          414287210         136356480
# 2017                          424160542         129194240
# 2018                          417380251         127916909
# 2019                          410679821         127263359
#
#       Nuclear steam turbine  Total thermal generation
# Year
# 2005               86829896                 244344460
# 2006               92418514                 240699455
# 2007               88190431                 249705324
# 2008               90585015                 240458756
# 2009               84991779                 221898695
# 2010               85526588                 228279782
# 2011               88291216                 233594546
# 2012               89492389                 226249141
# 2013               97584431                 233374393
# 2014              101207807                 235526678
# 2015               96045793                 233570257
# 2016               95687312                 232043792
# 2017               95565022                 224759262
# 2018               95029596                 222946505
# 2019               95469256                 222732615

# %%
# Output this combined data
merged_canada_data.to_csv("Transformed Data/Part 4.csv")

# %% [markdown]
# # Plotting

# %%
# File to Load
canada_data_filepath = "Transformed Data/Part 4.csv"

# Read Data File and store into Pandas DataFrames
canada_complete_data = pd.read_csv(canada_data_filepath)

# %% [markdown]
# ## Analysis of Production Growth of Each Rewanable Energy

# %%
# Generate and Format each renewable energy electricity production scatter plot in one figure
plt.scatter(canada_complete_data["Year"], canada_complete_data["Hydraulic turbine"]/1000, color = "orange", s = 100, 
            marker = "o", label = "Hydraulic")
plt.scatter(canada_complete_data["Year"], canada_complete_data["Solar"]/1000, color = "navy", s = 100, marker = "+", 
            label = "Solar")
plt.scatter(canada_complete_data["Year"], canada_complete_data["Tidal power turbine"]/1000, color = "green", s = 100, 
            marker = "*",label = "Tidal")
plt.scatter(canada_complete_data["Year"], canada_complete_data["Wind power turbine"]/1000, color = "darkred", s = 100, 
            marker = "s", label = "Wind")
plt.scatter(canada_complete_data["Year"], canada_complete_data["Other types of electricity generation"]/1000, 
            color = "indigo", s = 100, marker = "x", label = "Other")
plt.scatter(canada_complete_data["Year"], canada_complete_data["Total renewable energy generation"]/1000, 
            color = "dimgrey", s = 100, marker = "p",label = "Total")
plt.xticks(canada_complete_data["Year"], canada_complete_data["Year"], rotation = 45)
plt.xlim(2004,2020)
plt.ylim(-50000, 450000)
plt.xlabel("Year")
plt.ylabel("Electricty Production (Gigawatt Hours)")
plt.title("Annual Electricity Production by Renewable Energy (2005 - 2019)")
plt.legend(loc="right")
plt.tight_layout()
plt.savefig("Plots\Question 5 - Time vs. Types of Renewable Sources for Canada.png", bbox_inches = "tight")

# %%
# Generate and Format a line graph for electricity production by solar, wind, and other source to see the capacity growth trend 
plt.plot(canada_complete_data["Year"], canada_complete_data["Solar"]/1000, color = "darkorange", linewidth = 2.5, 
         label = "Solar")
plt.plot(canada_complete_data["Year"], canada_complete_data["Tidal power turbine"]/1000, color = "green", linewidth = 2.5,
         label = "Tidal")
plt.plot(canada_complete_data["Year"], canada_complete_data["Other types of electricity generation"]/1000, linewidth = 2.5, 
         color = "royalblue", label = "Other")
plt.xticks(canada_complete_data["Year"], canada_complete_data["Year"], rotation = 45)
plt.xlim(2004,2020)
plt.ylim(-100, 3100)
plt.xlabel("Year")
plt.ylabel("Electricty Production (Gigawatt Hours)")
plt.title("Canada Electricity Production by Solar, Wind, and Other (2005 - 2019)")
plt.legend(loc="upper right")
plt.tight_layout()
plt.savefig("Plots\Question 5 - Closer Look of Time vs. Types of Renewable Sources Graph for Canada.png", bbox_inches = "tight")

# %% [markdown]
# ## Analysis of Production Growth of Each Oil Energy

# %%
# Generate and Format each oil energy electricity production scatter plot in one figure
plt.scatter(canada_complete_data["Year"], canada_complete_data["Combustion fuels"]/1000, color = "darkred", s = 80, 
            marker = "o", label = "Combustion fuels")
plt.scatter(canada_complete_data["Year"], canada_complete_data["Nuclear steam turbine"]/1000, color = "darkolivegreen", s = 80, 
            marker = "s",label = "Nuclear")
plt.scatter(canada_complete_data["Year"], canada_complete_data["Total thermal generation"]/1000, color = "darkslateblue", 
            s = 80, marker = "D", label = "Total")
plt.xticks(canada_complete_data["Year"], canada_complete_data["Year"], rotation = 45)
plt.xlim(2004,2020)
plt.ylim(0, 300000)
plt.xlabel("Year")
plt.ylabel("Electricty Production (Megawatt Hours)")
plt.title("Annual Electricity Production by Oil Energy (2005 - 2019)")
plt.legend(loc="lower right")
plt.tight_layout()
plt.savefig("Plots\Question 5 - Time vs. Types of Oil Sources for Canada.png", bbox_inches = "tight")

# %% [markdown]
# ## Comparing Renewable Energy and Oil Energy Production

# %%
# Generate and Format scatter plot of electricity production by total renewable energy and total oil energy
plt.scatter(canada_complete_data["Year"], canada_complete_data["Total renewable energy generation"]/1000, s= 80, 
            facecolor = "green", edgecolor = "black", label = "Renewable")
plt.scatter(canada_complete_data["Year"], canada_complete_data["Total thermal generation"]/1000, s= 80, 
            facecolor = "grey", edgecolor = "black", label = "Non-Renewable")
plt.xticks(canada_complete_data["Year"], canada_complete_data["Year"], rotation = 45)
plt.xlim(2004,2020)
plt.ylim(200000, 450000)
plt.xlabel("Year")
plt.ylabel("Electricty Production (Gigawatt Hours)")
plt.title("Electricity Production by Different Energy (2005 - 2019)")
plt.legend(loc = "right")
plt.tight_layout()
plt.savefig("Plots\Question 5 - Time vs. Oil and Renewable for Canada.png", bbox_inches = "tight")

# %%
# Calculate the regression line for renewable energy production
renewable_regression = st.linregress(canada_complete_data["Year"], 
                                     canada_complete_data["Total renewable energy generation"]/1000)
renewable_regression_line = renewable_regression[0] * canada_complete_data["Year"] + renewable_regression[1]

# %%
# Calculate the regression line for oil energy production
oil_regression = st.linregress(canada_complete_data["Year"], 
                                     canada_complete_data["Total thermal generation"]/1000)
oil_regression_line = oil_regression[0] * canada_complete_data["Year"] + oil_regression[1]

# %%
# Put two regression lines into the scatter plot generated above
plt.scatter(canada_complete_data["Year"], canada_complete_data["Total renewable energy generation"]/1000, s= 80, 
            facecolor = "green", edgecolor = "black", label = "Renewable")
plt.scatter(canada_complete_data["Year"], canada_complete_data["Total thermal generation"]/1000, s= 80, 
            facecolor = "dimgrey", edgecolor = "black", label = "Non-Renewable")
plt.plot(canada_complete_data["Year"], renewable_regression_line, color = "darkred")
plt.plot(canada_complete_data["Year"], oil_regression_line, color = "mediumblue")
plt.annotate("y =  " + str(round(renewable_regression[0],2)) + "x+  " + str(round(renewable_regression[1],2)), (2010,340000), 
             fontsize = 13, color = "darkred")
plt.annotate("y =  " + str(round(oil_regression[0],2)) + "x+  " + str(round(oil_regression[1],2)), (2010,250000), 
             fontsize = 13, color = "mediumblue")
plt.xticks(canada_complete_data["Year"], canada_complete_data["Year"], rotation = 45)
plt.xlim(2004,2020)
plt.ylim(200000, 450000)
plt.xlabel("Year")
plt.ylabel("Electricty Production (Gigawatt Hours)")
plt.title("Electricity Production by Different Energy (2005 - 2019)")
plt.legend(loc = "best")
plt.tight_layout()
plt.savefig("Plots\Question 5 - Time vs. Oil and Renewable (with Regression) for Canada.png", bbox_inches = "tight")

# %% [markdown]
# ## Relationship between Canadian Dollar (Index) and Energy Source

# %%
## Use subplots to create energy production line graph and currency line graph in one figure with two y-axis
fig, ax1 = plt.subplots()

fig1, = ax1.plot(canada_complete_data["Year"], canada_complete_data["Total renewable energy generation"]/1000, 
                color = "forestgreen", linewidth = 1, label = "a")
fig2, = ax1.plot(canada_complete_data["Year"], canada_complete_data["Total thermal generation"]/1000, color = "dimgrey", 
                linewidth = 1, label = "b")
plt.xticks(canada_complete_data["Year"], canada_complete_data["Year"], rotation = 45)
plt.xlim(2004,2020)
plt.ylim(200000, 450000)
plt.xlabel("Year")
plt.ylabel("Electricty Production (Gigawatt Hours)")
plt.title("Electricity Production by Different Energy (2005 - 2019)")

ax2 = ax1.twinx()
fig3, = ax2.plot(canada_complete_data["Year"], canada_complete_data["Candian Dollar Index"], color = "darkred", 
                       linewidth = 1, label = "dfad")

ax2.set_ylabel("Canadian Dollar (Index)")
plt.legend([fig1,fig2,fig3], ["renewable", "non-renewable", "CAD Index"], loc = "right")
plt.tight_layout()
plt.savefig("Plots\Question 6 - Sources vs. CAD Index.png", bbox_inches = "tight")
