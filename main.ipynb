# %%
# Run all notebooks from the current folder
# %run "Part 1.ipynb"
# %run "Part 2.ipynb"
# %run "Part 3.ipynb"
# %run "Part 4.ipynb"

# Figures are plotted as below
# Refer to Readme and Powerpoint file for analysis and findings
